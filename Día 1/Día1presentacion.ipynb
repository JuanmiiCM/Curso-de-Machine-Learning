# %%
lista = [1,2,3,1]
lista[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-4d43586469ee> in <module>
#       1 lista = [1,2,3,1]
# ----> 2 lista[4]
#
# IndexError: list index out of range

# %%
lista.append(5)

# %%
print(lista)
# Out:
# [1, 2, 3, 1, 5]

# %%
pos = 1
elem = 0
lista.insert(pos, elem)

# %%
print(lista)
# Out:
# [1, 0, 2, 3, 1, 5]

# %%
# tuplas
tupla = (1,2,3,1)
print(tupla)
# Out:
# (1, 2, 3, 1)

# %%
# conjunto
conjunto = {1,2,3,1}
print(conjunto)
# Out:
# {1, 2, 3}

# %%
# Diccionario
diccionario = {0: 1, 1:2, 2:3 , "Luis" : "Soy Yo"}
print(diccionario["Luis"])
diccionario["Luis"] = 7
print(diccionario["Luis"])
# Out:
# Soy Yo
# 7
